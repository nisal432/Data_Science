# %%
import pandas as pd
import numpy as np

# %%
series_obj = pd.Series([1,2,3,4,5,6,19,10],dtype='Float64', name='First Series')
series_obj
#creating series object using list
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6    19.0
# 7    10.0
# Name: First Series, dtype: Float64

# %%
series_obj2 = pd.Series(np.arange(10), dtype=bool, name='numpy_series')
series_obj2
#everyting except 0 converted to True
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: numpy_series, dtype: bool

# %%
series_obj = pd.Series({'math':90,'science':100,'opt':44,"nepali":100,'English':105,'Business':'140'})

# %% [markdown]
# **Will be slicing Series and will be using some Series Methods**

# %%
series_obj.head()
# Out:
# math        90
# science    100
# opt         44
# nepali     100
# English    105
# dtype: object

# %%
series_obj.value_counts()# basically will give you the total count of each values of the series
# Out:
# 100    2
# 90     1
# 44     1
# 105    1
# 140    1
# Name: count, dtype: int64

# %%
series_obj[:]
# Out:
# math         90
# science     100
# opt          44
# nepali      100
# English     105
# Business    140
# dtype: object

# %%
#printing series from 2 to 4
series_obj[1:4]
# Out:
# science    100
# opt         44
# nepali     100
# dtype: object

# %%
series_obj.name = "Marks"

# %%
series_obj
# Out:
# math         90
# science     100
# opt          44
# nepali      100
# English     105
# Business    140
# Name: Marks, dtype: object

# %%
series_obj[::2] #printing series by jumping two step each
# Out:
# math        90
# opt         44
# English    105
# Name: Marks, dtype: object
